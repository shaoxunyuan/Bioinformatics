# %% [markdown]
# # 序列比对实验
#
# 本实验将学习如何使用Python进行序列比对分析。
#
# ## 实验目标
# - 理解序列比对的基本概念
# - 掌握全局比对和局部比对的区别
# - 学会使用Biopython进行序列比对
# - 理解比对得分和相似性计算

# %%
from Bio import pairwise2
from Bio.pairwise2 import format_alignment
from Bio.Seq import Seq

print("Biopython导入成功")

# %% [markdown]
# ## 1. 全局比对
#
# 全局比对适用于长度相近、整体同源的序列。

# %%
seq1 = "ATGCGATCGATCGATCG"
seq2 = "ATGCGATCGATCGATCG"

alignments = pairwise2.align.globalxx(seq1, seq2)

print("全局比对结果:")
for alignment in alignments[:1]:
    print(format_alignment(*alignment))

# %% [markdown]
# ## 2. 局部比对
#
# 局部比对用于寻找高相似性片段。

# %%
seq3 = "ATGCGATCG"
seq4 = "ATGCGATCGATCGATCGATCGATCG"

local_alignments = pairwise2.align.localxx(seq3, seq4)

print("局部比对结果:")
for alignment in local_alignments[:1]:
    print(format_alignment(*alignment))

# %% [markdown]
# ## 3. 带得分的比对
#
# 使用不同的得分矩阵进行比对。

# %%
seq5 = "ATGCGATCGATCGATCG"
seq6 = "ATGCGATCGATCGATCG"

score_alignments = pairwise2.align.globalms(seq5, seq6, 2, -1, -0.5, -0.1)

print("带得分的全局比对结果:")
for alignment in score_alignments[:1]:
    print(format_alignment(*alignment))

# %% [markdown]
# ## 4. 练习
#
# ### 练习1
# 创建两个不同的DNA序列，进行全局比对，并解释结果。
#
# ### 练习2
# 创建一个短序列和一个长序列，进行局部比对，观察结果。
#
# ### 练习3
# 修改得分矩阵参数，观察比对结果的变化。

# %%
# 在这里编写你的练习代码

# 练习1
seq_a = "YOUR_SEQUENCE_A"
seq_b = "YOUR_SEQUENCE_B"

# 进行比对...

# 练习2
# 在这里编写代码

# 练习3
# 在这里编写代码

# %% [markdown]
# ## 5. 思考题
#
# 1. 全局比对和局部比对的主要区别是什么？
# 2. 在什么情况下应该使用全局比对？
# 3. 得分矩阵中的参数如何影响比对结果？
